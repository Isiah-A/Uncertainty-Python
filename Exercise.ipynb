# %% [markdown]
# For each of the following, write a function, and repeatedly use it to simulate
#    the probability of an event occurring with the following chances:
#    1. $\frac{2}{7}$
#    2. $\frac{1}{10}$
#    3. $\frac{1}{100}$
#    4. $1$

# %%
import random

def simulate(sim):
    if random.random() <= sim:
        return "No"
    else:
        return "Yes"

# %%
num_of_reps = 10000
sample = [simulate(1/100) for repeats in range(num_of_reps)]

# %%
sample
# Out:
# ['Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'No',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
#  'Yes',
# ...

# %%
sum(token == "No" for token in sample) / num_of_reps
# Out:
# 0.0107

# %%
simulate(2/7)
# Out:
# 'No'

# %%
simulate(1/10)
# Out:
# 'Yes'

# %%
simulate(1/100)
# Out:
# 'Yes'

# %%
simulate(9/10)
# Out:
# 'No'

# %% [markdown]
# Write a function, and repeatedly use it to simulate the probability of
#    selecting a red token from each of the following configurations:
#    1. A bag with 4 red tokens and 4 green tokens.
#    2. A bag with 4 red tokens, 4 green tokens and 10 yellow tokens.
#    3. A bag with 0 red tokens, 4 green tokens and 10 yellow tokens.

# %%
bag1 = ("Red","Red","Red","Red","Green","Green","Green","Green")

# %%
bag2 = ["Red"] * 4 + ["Green"] * 4 + ["Yellow"] * 10

# %%
bag2
# Out:
# ['Red',
#  'Red',
#  'Red',
#  'Red',
#  'Green',
#  'Green',
#  'Green',
#  'Green',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Yellow']

# %%
bag3 = ["Red"] * 0 + ["Green"] * 4 + ["Yellow"] * 10

# %%
bag3
# Out:
# ['Green',
#  'Green',
#  'Green',
#  'Green',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Yellow']

# %%
def simulator(sim):
    return random.choice(sim)

# %%
num_of_reps = 10000
sample = [simulator(bag2) for repeats in range(num_of_reps)]

# %%
sample
# Out:
# ['Yellow',
#  'Yellow',
#  'Yellow',
#  'Red',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Red',
#  'Green',
#  'Yellow',
#  'Yellow',
#  'Green',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Red',
#  'Red',
#  'Yellow',
#  'Green',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Green',
#  'Red',
#  'Yellow',
#  'Red',
#  'Yellow',
#  'Red',
#  'Green',
#  'Green',
#  'Red',
#  'Red',
#  'Yellow',
#  'Red',
#  'Yellow',
#  'Green',
#  'Green',
#  'Yellow',
#  'Yellow',
#  'Red',
#  'Yellow',
#  'Green',
#  'Green',
#  'Yellow',
#  'Red',
#  'Yellow',
#  'Red',
#  'Yellow',
#  'Yellow',
#  'Red',
#  'Yellow',
#  'Green',
#  'Yellow',
#  'Red',
#  'Yellow',
#  'Green',
#  'Green',
#  'Green',
#  'Yellow',
#  'Yellow',
#  'Green',
#  'Red',
#  'Red',
#  'Yellow',
#  'Green',
#  'Yellow',
#  'Yellow',
#  'Red',
#  'Red',
#  'Yellow',
#  'Green',
#  'Yellow',
#  'Red',
#  'Yellow',
#  'Yellow',
#  'Yellow',
#  'Green',
#  'Green',
#  'Yellow',
#  'Yellow',
# ...

# %%
sum(token == "Red" for token in sample) / num_of_reps
# Out:
# 0.2208

# %%
simulator(bag1)
# Out:
# 'Red'

# %%
simulator(bag2)
# Out:
# 'Green'

# %%
simulator(bag3)
# Out:
# 'Yellow'

# %% [markdown]
# 3. An experiment consists of selecting a token from a bag and spinning a coin. The bag contains 3 red tokens and 4 blue tokens. A token is selected at random from the bag, its colour is noted and then the token is returned to the bag.
#    1. Approximate the probability of picking a red token?
#    2. Approximate the probability of obtaining Heads?
#    3. If a heads is obtained, approximate the probability of having selected a red token.

# %%
thebag = ["Red Token"] * 3 + ["Blue Token"] * 4

# %%
thebag
# Out:
# ['Red Token',
#  'Red Token',
#  'Red Token',
#  'Blue Token',
#  'Blue Token',
#  'Blue Token',
#  'Blue Token']

# %%
pip install sympy
# Out:
# ...
#   Using cached sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Using cached sympy-1.13.3-py3-none-any.whl (6.2 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sympy as sym

# %%
def simulating(sim):
    return random.choice(sim)

# %%
num_of_reps = 10000
sample = [simulator(thebag) for repeats in range(num_of_reps)]

# %%
sample
# Out:
# ['Blue Token',
#  'Red Token',
#  'Red Token',
#  'Blue Token',
#  'Blue Token',
#  'Blue Token',
#  'Red Token',
#  'Red Token',
#  'Red Token',
#  'Red Token',
#  'Blue Token',
#  'Red Token',
#  'Blue Token',
#  'Blue Token',
#  'Blue Token',
#  'Blue Token',
#  'Red Token',
#  'Red Token',
#  'Red Token',
#  'Red Token',
#  'Blue Token',
#  'Red Token',
#  'Blue Token',
#  'Blue Token',
#  'Red Token',
#  'Blue Token',
#  'Blue Token',
#  'Red Token',
#  'Blue Token',
#  'Red Token',
#  'Blue Token',
#  'Blue Token',
#  'Red Token',
#  'Red Token',
#  'Blue Token',
#  'Blue Token',
#  'Blue Token',
#  'Blue Token',
#  'Blue Token',
#  'Blue Token',
#  'Red Token',
#  'Red Token',
#  'Blue Token',
#  'Red Token',
#  'Blue Token',
#  'Red Token',
#  'Blue Token',
#  'Blue Token',
#  'Red Token',
#  'Blue Token',
#  'Blue Token',
#  'Blue Token',
#  'Red Token',
#  'Red Token',
#  'Blue Token',
#  'Red Token',
#  'Blue Token',
#  'Blue Token',
#  'Blue Token',
#  'Red Token',
# ...

# %%
sum(token == "Red Token" for token in sample) / num_of_reps
# Out:
# 0.4327

# %%
sym.S (3)/(7) * sym.S (4)/(5) + sym.S (4) / (7) * sym.S(2) / (5) 
#3/7 = red token chance
#4/5 = proability of landing heads if red is selected
#4/7 = blue token chance
#2/5 = chance of landing heads if blue is selected
# Out:
# 4/7

# %% [markdown]
# If a heads is obtained, approximate the probability of having selected a red token.

# %%
sym.S (5) / (5) * sym.S (3) / (7) / (sym.S (4) / (7))
#5/5 = heads chance of being obtained
#3/7 = red token chance
#4/7 = blue token chance
# Out:
# 3/4

# %% [markdown]
# On a randomly chose day, the probability of an individual travelling to school by car, bicycle or on foot is $1/2$, $1/6$ and $1/3$ respectively. The probability of being late when using these methods of travel is $1/5$, $2/5$ and $1/10$ respectively.

# %%
late_chance = (sym.S(1)/2 * sym.S(1)/5) + (sym.S(1)/6 * sym.S(2)/5) + (sym.S(1)/3 * sym.S(1)/10)
late_chance
# Out:
# 1/5

# %%
late_on_feet = ((sym.S (1) / 10) * sym.S(1) / 3) / (sym.S(1) / 5)
late_on_feet
# Out:
# 1/6

# %%
not_late = 1 - late_chance
not_late
# Out:
# 4/5

# %%
not_late_on_feet = 1 - late_on_feet
not_late_on_feet
# Out:
# 5/6
